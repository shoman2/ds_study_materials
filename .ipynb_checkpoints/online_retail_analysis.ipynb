# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import os
os.getcwd()
# Out:
# 'C:\\Users\\tkim29'

# %%
data = pd.read_excel('Online Retail.xlsx')

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data.isnull().sum() ##Description, CustomerID 결측치 존재
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null datetime64[ns]
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
data['InvoiceNo'].unique()
# Out:
# array([536365, 536366, 536367, ..., 581585, 581586, 581587], dtype=object)

# %%
data[['StockCode']].head(3)
# Out:
#   StockCode
# 0    85123A
# 1     71053
# 2    84406B

# %%
data[data['Description'].isnull()].head()
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 622     536414     22139         NaN        56 2010-12-01 11:52:00        0.0
# 1970    536545     21134         NaN         1 2010-12-01 14:32:00        0.0
# 1971    536546     22145         NaN         1 2010-12-01 14:33:00        0.0
# 1972    536547     37509         NaN         1 2010-12-01 14:33:00        0.0
# 1987    536549    85226A         NaN         1 2010-12-01 14:34:00        0.0
#
#       CustomerID         Country
# 622          NaN  United Kingdom
# 1970         NaN  United Kingdom
# 1971         NaN  United Kingdom
# 1972         NaN  United Kingdom
# 1987         NaN  United Kingdom

# %%
data["Description_fillin"] = data["Description"]

# %%
data[['Description','Description_fillin']].head()
# Out:
#                            Description                   Description_fillin
# 0   WHITE HANGING HEART T-LIGHT HOLDER   WHITE HANGING HEART T-LIGHT HOLDER
# 1                  WHITE METAL LANTERN                  WHITE METAL LANTERN
# 2       CREAM CUPID HEARTS COAT HANGER       CREAM CUPID HEARTS COAT HANGER
# 3  KNITTED UNION FLAG HOT WATER BOTTLE  KNITTED UNION FLAG HOT WATER BOTTLE
# 4       RED WOOLLY HOTTIE WHITE HEART.       RED WOOLLY HOTTIE WHITE HEART.

# %%
data.loc[data["Description"].isnull(), "Description_fillin"] = 'No Comments'

# %%
data.isnull().sum()
# Out:
# InvoiceNo                  0
# StockCode                  0
# Description             1454
# Quantity                   0
# InvoiceDate                0
# UnitPrice                  0
# CustomerID            135080
# Country                    0
# Description_fillin         0
# dtype: int64

# %%
data['Real_Price'] = data['Quantity']*data['UnitPrice']

# %%
data['Real_Price'].head()
# Out:
# 0    15.30
# 1    20.34
# 2    22.00
# 3    20.34
# 4    20.34
# Name: Real_Price, dtype: float64

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'Description_fillin',
#        'CustomerID_fillin', 'Real_Price'],
#       dtype='object')

# %%
data['CustomerID_fillin'] = data['CustomerID']

# %%
data['CustomerID'].head()
# Out:
# 0    17850.0
# 1    17850.0
# 2    17850.0
# 3    17850.0
# 4    17850.0
# Name: CustomerID, dtype: float64

# %%
data.loc[data["CustomerID"].isnull(), "CustomerID_fillin"] = 99999

# %%
data['CustomerID_fillin'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# InvoiceNo                  0
# StockCode                  0
# Description             1454
# Quantity                   0
# InvoiceDate                0
# UnitPrice                  0
# CustomerID            135080
# Country                    0
# Description_fillin         0
# CustomerID_fillin          0
# Real_Price                 0
# dtype: int64

# %%
data.groupby('CustomerID')

# %%
data_gb = data.groupby(by='CustomerID_fillin', axis=0).sum()

# %%
data_gb = data_gb.drop('Quantity', axis=1)

# %%
data_gb = data_gb.drop('UnitPrice', axis=1)

# %%
data_gb = data_gb.drop('CustomerID', axis=1)

# %%
data_gb['CustomerID_fillin']==99999
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'CustomerID_fillin'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-243-027aef262182> in <module>
# ...

# %%
data_country = data.groupby(by='Country').sum()

# %%
country_df = data_country[['Real_Price']]

# %%
country_df_index=country_df.reset_index()

# %%
country_df_index['Real_Price']
# Out:
# 0     1.370773e+05
# 1     1.015432e+04
# 2     5.484000e+02
# 3     4.091096e+04
# 4     1.143600e+03
# 5     3.666380e+03
# 6     2.008629e+04
# 7     1.294629e+04
# 8     7.077200e+02
# 9     1.876814e+04
# 10    2.632768e+05
# 11    1.291750e+03
# 12    2.232674e+04
# 13    1.974039e+05
# 14    2.216982e+05
# 15    4.710520e+03
# 16    1.011704e+04
# 17    4.310000e+03
# 18    7.907820e+03
# 19    1.689051e+04
# 20    3.534062e+04
# 21    1.693880e+03
# 22    1.661060e+03
# 23    2.505470e+03
# 24    2.846615e+05
# 25    3.516346e+04
# 26    7.213140e+03
# 27    2.936702e+04
# 28    1.002310e+03
# 29    1.311700e+02
# 30    9.120390e+03
# 31    5.477458e+04
# 32    3.659591e+04
# 33    5.638535e+04
# 34    1.730920e+03
# 35    1.902280e+03
# 36    8.187806e+06
# 37    4.749790e+03
# Name: Real_Price, dtype: float64

# %%
data_inv = data.groupby(by='InvoiceNo',)

# %%
data_inv.head(3)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10        536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11        536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# 21        536368     22960             JAM MAKING SET WITH JARS         6
# 22        536368     22913          RED COAT RACK PARIS FASHION         3
# 23        536368     22912       YELLOW COAT RACK PARIS FASHION         3
# 25        536369     21756             BATH BUILDING BLOCK WORD         3
# ...
